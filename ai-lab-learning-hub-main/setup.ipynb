# %%
pip install uv
# Out:
# ...
#   Using cached uv-0.6.8-py3-none-win_amd64.whl.metadata (11 kB)
# Using cached uv-0.6.8-py3-none-win_amd64.whl (17.3 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python --version
# Out:
# Python 3.12.9
